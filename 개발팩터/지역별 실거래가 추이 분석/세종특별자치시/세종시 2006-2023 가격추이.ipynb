# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
sejong05_06 = pd.read_csv('/home/subin/다운로드/아파트(매매)__실거래가_세종_05-06.csv', encoding='cp949', header=15)
sejong06_07 = pd.read_csv('/home/subin/다운로드/아파트(매매)__실거래가_세종_06-07.csv', encoding='cp949', header=15)
sejong07_08 = pd.read_csv('/home/subin/다운로드/아파트(매매)__실거래가_세종_07-08.csv', encoding='cp949', header=15)
sejong08_09 = pd.read_csv('/home/subin/다운로드/아파트(매매)__실거래가_세종_08-09.csv', encoding='cp949', header=15)
sejong09_10 = pd.read_csv('/home/subin/다운로드/아파트(매매)__실거래가_세종_09-10.csv', encoding='cp949', header=15)
sejong10_11 = pd.read_csv('/home/subin/다운로드/아파트(매매)__실거래가_세종_10-11.csv', encoding='cp949', header=15)
sejong11_12 = pd.read_csv('/home/subin/다운로드/아파트(매매)__실거래가_세종_11-12.csv', encoding='cp949', header=15)
sejong12_13 = pd.read_csv('/home/subin/다운로드/아파트(매매)__실거래가_세종_12-13.csv', encoding='cp949', header=15)
sejong13_14 = pd.read_csv('/home/subin/다운로드/아파트(매매)__실거래가_세종_13-14.csv', encoding='cp949', header=15)
sejong14_15 = pd.read_csv('/home/subin/다운로드/아파트(매매)__실거래가_세종_14-15.csv', encoding='cp949', header=15)
sejong15_16 = pd.read_csv('/home/subin/다운로드/아파트(매매)__실거래가_세종_15-16.csv', encoding='cp949', header=15)
sejong16_17 = pd.read_csv('/home/subin/다운로드/아파트(매매)__실거래가_세종_16-17.csv', encoding='cp949', header=15)
sejong17_18 = pd.read_csv('/home/subin/다운로드/아파트(매매)__실거래가_세종_17-18.csv', encoding='cp949', header=15)
sejong18_19 = pd.read_csv('/home/subin/다운로드/아파트(매매)__실거래가_세종_18-19.csv', encoding='cp949', header=15)
sejong19_20 = pd.read_csv('/home/subin/다운로드/아파트(매매)__실거래가_세종_19-20.csv', encoding='cp949', header=15)
sejong20_21 = pd.read_csv('/home/subin/다운로드/아파트(매매)__실거래가_세종_20-21.csv', encoding='cp949', header=15)
sejong21_22 = pd.read_csv('/home/subin/다운로드/아파트(매매)__실거래가_세종_21-22.csv', encoding='cp949', header=15)
sejong22_23 = pd.read_csv('/home/subin/다운로드/아파트(매매)__실거래가_세종_22-23.csv', encoding='cp949', header=15)

sejong05_23 = pd.concat([sejong05_06, sejong06_07, sejong07_08, sejong08_09, sejong09_10, sejong10_11, sejong11_12, sejong12_13, sejong13_14, sejong14_15,
                        sejong15_16, sejong16_17, sejong17_18, sejong18_19, sejong19_20, sejong20_21, sejong21_22, sejong22_23])
sejong05_23['시군구'].unique()
# Out:
# array(['세종특별자치시 금남면 용포리', '세종특별자치시 부강면 부강리', '세종특별자치시 소정면 운당리',
#        '세종특별자치시 연동면 명학리', '세종특별자치시 연서면 봉암리', '세종특별자치시 전동면 노장리',
#        '세종특별자치시 전의면 동교리', '세종특별자치시 전의면 유천리', '세종특별자치시 조치원읍 교리',
#        '세종특별자치시 조치원읍 남리', '세종특별자치시 조치원읍 번암리', '세종특별자치시 조치원읍 서창리',
#        '세종특별자치시 조치원읍 신안리', '세종특별자치시 조치원읍 신흥리', '세종특별자치시 조치원읍 정리',
#        '세종특별자치시 조치원읍 죽림리', '세종특별자치시 조치원읍 침산리', '세종특별자치시 조치원읍 원리',
#        '세종특별자치시 한솔동', '세종특별자치시 나성동', '세종특별자치시 도담동', '세종특별자치시 아름동',
#        '세종특별자치시 어진동', '세종특별자치시 장군면 금암리', '세종특별자치시 조치원읍 상리', '세종특별자치시 종촌동',
#        '세종특별자치시 고운동', '세종특별자치시 보람동', '세종특별자치시 새롬동', '세종특별자치시 소담동',
#        '세종특별자치시 다정동', '세종특별자치시 대평동', '세종특별자치시 반곡동', '세종특별자치시 가람동',
#        '세종특별자치시 소정면 소정리', '세종특별자치시 해밀동', '세종특별자치시 집현동'], dtype=object)

# %% [markdown]
# * 세종특별자치시는 '시군구' 분류가 없어, 바로 '읍면동'으로 분류

# %%
sejong05_23['시도'] = sejong05_23['시군구'].str.split().str[0]
sejong05_23['리'] = sejong05_23['시군구'].str.split().str[2]
sejong05_23['읍면동'] = sejong05_23['시군구'].str.split().str[1]

sejong05_23['거래금액(만원)'] = sejong05_23['거래금액(만원)'].str.replace(',', '').astype(int)
sejong05_23['계약년월'] = sejong05_23['계약년월'].astype(str)

# %%
sejong05_23.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49783 entries, 0 to 4089
# Data columns (total 19 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시군구       49783 non-null  object
#  1   번지        49772 non-null  object
#  2   본번        49783 non-null  object
#  3   부번        49783 non-null  int64
#  4   단지명       49783 non-null  object
#  5   전용면적(㎡)   49783 non-null  float64
#  6   계약년월      49783 non-null  object
#  7   계약일       49783 non-null  int64
#  8   거래금액(만원)  49783 non-null  int64
#  9   층         49783 non-null  int64
#  10  건축년도      49782 non-null  float64
#  11  도로명       49783 non-null  object
#  12  해제사유발생일   1312 non-null   float64
#  13  등기신청일자    49783 non-null  object
#  14  거래유형      49783 non-null  object
#  15  중개사소재지    49783 non-null  object
#  16  시도        49783 non-null  object
#  17  리         20382 non-null  object
#  18  읍면동       49783 non-null  object
# dtypes: float64(3), int64(4), object(12)
# ...

# %%
avg_sejong05_23 = sejong05_23.groupby(['읍면동', '계약년월']).mean().reset_index()
avg_sejong05_23 = avg_sejong05_23.sort_values(by=['계약년월', '읍면동'])
avg_sejong05_23
# Out:
# <ipython-input-8-639b281166d6>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_sejong05_23 = sejong05_23.groupby(['읍면동', '계약년월']).mean().reset_index()
#        읍면동    계약년월           부번    전용면적(㎡)        계약일      거래금액(만원)  \
# 104    금남면  200601     0.000000  43.632430  15.925926   4600.370370
# 1650   연서면  200601     0.000000  60.956222  12.055556   7153.333333
# 2159  조치원읍  200601     0.581395  64.840651  15.139535   7830.604651
# 105    금남면  200602     0.000000  44.061725  16.437500   4897.812500
# 786    부강면  200602     5.000000  54.815000  26.000000   4000.000000
# ...    ...     ...          ...        ...        ...           ...
# 2369  조치원읍  202307     0.125000  88.730731  17.187500  26593.750000
# 2482   종촌동  202307     0.000000  81.687626  13.777778  51494.444444
# ...

# %%
dong_list = avg_sejong05_23['읍면동'].unique().tolist()
dong_list
# Out:
# ['금남면',
#  '연서면',
#  '조치원읍',
#  '부강면',
#  '소정면',
#  '연동면',
#  '전의면',
#  '전동면',
#  '한솔동',
#  '나성동',
#  '어진동',
#  '종촌동',
#  '도담동',
#  '아름동',
#  '장군면',
#  '고운동',
#  '소담동',
#  '보람동',
#  '새롬동',
#  '대평동',
#  '다정동',
#  '반곡동',
#  '가람동',
#  '해밀동',
#  '집현동']

# %%
name0 = avg_sejong05_23[avg_sejong05_23['읍면동']==dong_list[0]]
name1 = avg_sejong05_23[avg_sejong05_23['읍면동']==dong_list[1]]
name2 = avg_sejong05_23[avg_sejong05_23['읍면동']==dong_list[2]]
name3 = avg_sejong05_23[avg_sejong05_23['읍면동']==dong_list[3]]
name4 = avg_sejong05_23[avg_sejong05_23['읍면동']==dong_list[4]]
name5 = avg_sejong05_23[avg_sejong05_23['읍면동']==dong_list[5]]
name6 = avg_sejong05_23[avg_sejong05_23['읍면동']==dong_list[6]]
name7 = avg_sejong05_23[avg_sejong05_23['읍면동']==dong_list[7]]
name8 = avg_sejong05_23[avg_sejong05_23['읍면동']==dong_list[8]]
name9 = avg_sejong05_23[avg_sejong05_23['읍면동']==dong_list[9]]
name10 = avg_sejong05_23[avg_sejong05_23['읍면동']==dong_list[10]]
name11 = avg_sejong05_23[avg_sejong05_23['읍면동']==dong_list[11]]
name12 = avg_sejong05_23[avg_sejong05_23['읍면동']==dong_list[12]]
name13 = avg_sejong05_23[avg_sejong05_23['읍면동']==dong_list[13]]
name14 = avg_sejong05_23[avg_sejong05_23['읍면동']==dong_list[14]]
name15 = avg_sejong05_23[avg_sejong05_23['읍면동']==dong_list[15]]
name16 = avg_sejong05_23[avg_sejong05_23['읍면동']==dong_list[16]]
name17 = avg_sejong05_23[avg_sejong05_23['읍면동']==dong_list[17]]
name18 = avg_sejong05_23[avg_sejong05_23['읍면동']==dong_list[18]]
name19 = avg_sejong05_23[avg_sejong05_23['읍면동']==dong_list[19]]
name20 = avg_sejong05_23[avg_sejong05_23['읍면동']==dong_list[20]]
name21 = avg_sejong05_23[avg_sejong05_23['읍면동']==dong_list[21]]
name22 = avg_sejong05_23[avg_sejong05_23['읍면동']==dong_list[22]]
name23 = avg_sejong05_23[avg_sejong05_23['읍면동']==dong_list[23]]
name24 = avg_sejong05_23[avg_sejong05_23['읍면동']==dong_list[24]]

# %% [markdown]
# * 그래프 x축은 가장 첫 번째로 형성되는 plot을 따라가므로, 2006.01부터 2023.07까지 모든 계약년월을 가지고 있는 '읍면동'을 가장 첫 번째 줄에 배치 (=조치원읍)

# %%
name2['계약년월'].nunique()
# Out:
# 211

# %%
plt.figure(figsize=(60,16))
plt.plot(name2['계약년월'], name2['거래금액(만원)'], label = dong_list[2], color="#f66571") # 조치원읍
plt.plot(name0['계약년월'], name0['거래금액(만원)'], label = dong_list[0], color="#eaa1a3") # 금남면
plt.plot(name1['계약년월'], name1['거래금액(만원)'], label = dong_list[1], color = "#8f6fe5") # 연서면
plt.plot(name3['계약년월'], name3['거래금액(만원)'], label = dong_list[3], color = "#ff9184") # 부강면
plt.plot(name4['계약년월'], name4['거래금액(만원)'], label = dong_list[4], color="#f9ae85") # 소정면
plt.plot(name5['계약년월'], name5['거래금액(만원)'], label = dong_list[5], color = "#768ee0") # 연동면
plt.plot(name6['계약년월'], name6['거래금액(만원)'], label = dong_list[6], color="#ff8439") # 전의면
plt.plot(name7['계약년월'], name7['거래금액(만원)'], label = dong_list[7], color = "#feb137") # 전동면
plt.plot(name8['계약년월'], name8['거래금액(만원)'], label = dong_list[8], color = "#fcd47d") # 한솔동
plt.plot(name9['계약년월'], name9['거래금액(만원)'], label = dong_list[9], color="#74ceb9") # 나성동
plt.plot(name10['계약년월'], name10['거래금액(만원)'], label = dong_list[10], color="#00ac8d") # 어진동
plt.plot(name11['계약년월'], name11['거래금액(만원)'], label = dong_list[11], color="#aec47a") # 종촌동
plt.plot(name12['계약년월'], name12['거래금액(만원)'], label = dong_list[12], color = "#7caa52") # 도담동
plt.plot(name13['계약년월'], name13['거래금액(만원)'], label = dong_list[13], color="#3d8135") # 아름동
plt.plot(name14['계약년월'], name14['거래금액(만원)'], label = dong_list[14], color = "#665387") # 장군면
plt.plot(name15['계약년월'], name15['거래금액(만원)'], label = dong_list[15], color="#a88bb4") # 고운동
plt.plot(name16['계약년월'], name16['거래금액(만원)'], label = dong_list[16], color = "black") # 소담동
plt.plot(name17['계약년월'], name17['거래금액(만원)'], label = dong_list[17], color = "#83a296") # 보람동
plt.plot(name18['계약년월'], name18['거래금액(만원)'], label = dong_list[18], color="#5b5b5b") # 새롬동
plt.plot(name19['계약년월'], name19['거래금액(만원)'], label = dong_list[19], color = "#888888") # 대평동
plt.plot(name20['계약년월'], name20['거래금액(만원)'], label = dong_list[20], color = "blue") # 다정동
plt.plot(name21['계약년월'], name21['거래금액(만원)'], label = dong_list[21], color = "#72b8db") # 반곡동
plt.plot(name22['계약년월'], name22['거래금액(만원)'], label = dong_list[22], color = "#5a98b7") # 가람동
plt.plot(name23['계약년월'], name23['거래금액(만원)'], label = dong_list[23], color = "#90612b") # 해밀동
plt.plot(name24['계약년월'], name24['거래금액(만원)'], label = dong_list[24], color = "#ac3cd9") # 집현동
plt.grid('-')
plt.rc('font', family='NanumGothic')
plt.xticks(rotation=45)
plt.legend()

# %%
avg_sejong05_23
# Out:
#        시군구    계약년월           부번    전용면적(㎡)        계약일      거래금액(만원)  \
# 104    금남면  200601     0.000000  43.632430  15.925926   4600.370370
# 1650   연서면  200601     0.000000  60.956222  12.055556   7153.333333
# 2159  조치원읍  200601     0.581395  64.840651  15.139535   7830.604651
# 105    금남면  200602     0.000000  44.061725  16.437500   4897.812500
# 786    부강면  200602     5.000000  54.815000  26.000000   4000.000000
# ...    ...     ...          ...        ...        ...           ...
# 2369  조치원읍  202307     0.125000  88.730731  17.187500  26593.750000
# 2482   종촌동  202307     0.000000  81.687626  13.777778  51494.444444
# 2493   집현동  202307  3501.000000  59.855000  11.000000  41000.000000
# 2626   한솔동  202307     0.000000  75.031250  11.062500  48237.500000
# 2646   해밀동  202307     1.000000  82.340000  13.166667  61244.500000
#
#               층         건축년도     해제사유발생일
# 104    6.555556  2000.000000         NaN
# 1650   4.833333  2002.000000         NaN
# ...

# %%
name_order = pd.DataFrame()
name_order['읍면동'] = dong_list
name_order
# Out:
#      읍면동
# 0    금남면
# 1    연서면
# 2   조치원읍
# 3    부강면
# 4    소정면
# 5    연동면
# 6    전의면
# 7    전동면
# 8    한솔동
# 9    나성동
# 10   어진동
# 11   종촌동
# 12   도담동
# 13   아름동
# 14   장군면
# 15   고운동
# 16   소담동
# 17   보람동
# 18   새롬동
# 19   대평동
# 20   다정동
# 21   반곡동
# 22   가람동
# 23   해밀동
# 24   집현동

# %% [markdown]
# 1. 상승률이 저조한 지역
# - 조치원읍 / 부강면 / 소정면 / 전의면 / 전동면 / 장군면 / 나성동 <br>
# * 조치원읍은 x축 순서를 위해 모든 경우 삽입
# * 나성동은 상승한 부분이 있으나, 그 정도가 다른 지역에 비해 눈에 띄지 않아 상승률이 저조한 지역에 포함

# %%
plt.figure(figsize=(60,16))

plt.plot(name2['계약년월'], name2['거래금액(만원)'], label = dong_list[2], color="#f66571") # 조치원읍
plt.plot(name3['계약년월'], name3['거래금액(만원)'], label = dong_list[3], color = "#ff9184") # 부강면
plt.plot(name4['계약년월'], name4['거래금액(만원)'], label = dong_list[4], color="#f9ae85") # 소정면
plt.plot(name6['계약년월'], name6['거래금액(만원)'], label = dong_list[6], color="#ff8439") # 전의면
plt.plot(name7['계약년월'], name7['거래금액(만원)'], label = dong_list[7], color = "#feb137") # 전동면
plt.plot(name14['계약년월'], name14['거래금액(만원)'], label = dong_list[14], color = "#665387") # 장군면
plt.plot(name9['계약년월'], name9['거래금액(만원)'], label = dong_list[9], color="#74ceb9") # 나성동

plt.grid('-')
plt.rc('font', family='NanumGothic')
plt.title('세종특별자치시 2006-2023 가격추이 - 상승률 저조')
plt.xticks(rotation=45)
plt.legend()

# %% [markdown]
# 2. 후반부 소폭 상승한 지역

# %%
plt.figure(figsize=(60,16))
plt.plot(name2['계약년월'], name2['거래금액(만원)'], label = dong_list[2], color="#f66571") # 조치원읍
plt.plot(name0['계약년월'], name0['거래금액(만원)'], label = dong_list[0], color="#eaa1a3") # 금남면
plt.plot(name1['계약년월'], name1['거래금액(만원)'], label = dong_list[1], color = "#8f6fe5") # 연서면
plt.plot(name5['계약년월'], name5['거래금액(만원)'], label = dong_list[5], color = "#768ee0") # 연동면
plt.plot(name9['계약년월'], name9['거래금액(만원)'], label = dong_list[9], color="#74ceb9") # 나성동

plt.grid('-')
plt.rc('font', family='NanumGothic')
plt.title('세종특별자치시 2006-2023 가격추이 - 소폭 상승')
plt.xticks(rotation=45)
plt.legend()

# %% [markdown]
# 3. 큰 상승폭을 보인 지역

# %%
plt.figure(figsize=(60,16))
plt.plot(name2['계약년월'], name2['거래금액(만원)'], label = dong_list[2], color="#f66571") # 조치원읍
plt.plot(name8['계약년월'], name8['거래금액(만원)'], label = dong_list[8], color = "#fcd47d") # 한솔동
plt.plot(name11['계약년월'], name11['거래금액(만원)'], label = dong_list[11], color="#aec47a") # 종촌동
plt.plot(name13['계약년월'], name13['거래금액(만원)'], label = dong_list[13], color="#3d8135") # 아름동
plt.plot(name15['계약년월'], name15['거래금액(만원)'], label = dong_list[15], color="#a88bb4") # 고운동
plt.plot(name16['계약년월'], name16['거래금액(만원)'], label = dong_list[16], color = "black") # 소담동
plt.plot(name17['계약년월'], name17['거래금액(만원)'], label = dong_list[17], color = "#83a296") # 보람동
plt.plot(name18['계약년월'], name18['거래금액(만원)'], label = dong_list[18], color="#5b5b5b") # 새롬동
plt.plot(name19['계약년월'], name19['거래금액(만원)'], label = dong_list[19], color = "#888888") # 대평동
plt.plot(name20['계약년월'], name20['거래금액(만원)'], label = dong_list[20], color = "blue") # 다정동
plt.plot(name21['계약년월'], name21['거래금액(만원)'], label = dong_list[21], color = "#72b8db") # 반곡동

plt.grid('-')
plt.rc('font', family='NanumGothic')
plt.title('세종특별자치시 2006-2023 가격추이 - 대폭 상승')
plt.xticks(rotation=45)
plt.legend()

# %% [markdown]
# 4. 등락폭이 큰 지역 (=경향성을 찾기 어려운 지역)

# %%
plt.figure(figsize=(60,16))
plt.plot(name2['계약년월'], name2['거래금액(만원)'], label = dong_list[2], color="#f66571") # 조치원읍
plt.plot(name10['계약년월'], name10['거래금액(만원)'], label = dong_list[10], color="#00ac8d") # 어진동
plt.plot(name12['계약년월'], name12['거래금액(만원)'], label = dong_list[12], color = "#7caa52") # 도담동
plt.plot(name22['계약년월'], name22['거래금액(만원)'], label = dong_list[22], color = "#5a98b7") # 가람동
plt.plot(name23['계약년월'], name23['거래금액(만원)'], label = dong_list[23], color = "#90612b") # 해밀동
plt.plot(name24['계약년월'], name24['거래금액(만원)'], label = dong_list[24], color = "#ac3cd9") # 집현동
plt.grid('-')
plt.rc('font', family='NanumGothic')
plt.title('세종특별자치시 2006-2023 가격추이 - 등락폭 大')
plt.xticks(rotation=45)
plt.legend()

# %%
from IPython.display import Image
Image('/home/subin/다운로드/팩터 논문/세종시 개발호재/세종특별자치시 행정구역.jpg')

# %% [markdown]
# 사진 출처 : https://www.sejong.go.kr/index.jsp

# %% [markdown]
# <h3>'~동'으로 끝나는 지역들이 행정수도 건설 과정에서 새롭게 생긴 지역들 (=개발된 지역)</h3>
#
# * 고운동, 아름동, 종촌동, 다정동, 새롬동, 한솔동, 대평동, 보람동, 소담동, 반곡동 (세종동을 기준으로 측면 V자 형성)
# * 실제로 이 지역들이 2011년 또는 2016년에 실거래가 데이터 생성됨
# * 해당 지역들의 가격대가 높게 형성됨
# * 해당 지역들끼리는 비슷한 증감 양상을 보임
# * 이 중, 대평동이 가장 높게, 고운동이 가장 낮게 나타남
#
# <br>
#
# <h3>'~면'으로 끝나는 지역들이 개발이 비교적 적게 진행된 지역들</h3>
#
# * 부강면, 소정면, 전의면, 전동면, 장군면, 조치원읍, 나성동
# * 나성동은 상승률이 저조한 2022.12부터 급등, 2023.02 최고치 기록 (최고치는 약 4억원대 초반으로, 대폭 상승한 지역 중 최하위 지역인 '고운동'의 2023년 가격과 비슷)
# * 나성동은 이 구간 외에 약 1~1.5억원 형성
#
# <br>
#
# <h3>소폭 상승한 지역들 - 신도심('~동') 인접지역 or 조치원읍 인접지역</h3>
#
# * 금남면, 연서면, 연동면, 나성동
# * 2020.05부터 약 2-3배 수준으로 급상승했다가 하락한 모습, 대폭 상승한 지역들('~동')은 2020.05까지 완만히 증가하다가 2020.06부터 약 2-3배 수준으로 급상승했다가 하락
# * 같은 기간 동안 변화한 절대적 수치의 차이로 전체 가격추이에서 기울기 차가 나타났으나, 급등 직전 가격에 비해 몇 배 상승했는지는 대폭/소폭 상승 지역들이 서로 비슷하게 나타남
# * 금남면은 토지 대부분이 농림지역/보전관리지역 등으로 산지지형이며 개발된 면적이 전체 농토의 1% 정도로 보이나, 보람동'행정중심복합도시3-1생활권'에 인접한 곳에 제1종일반주거지역이 작게 형성되어있음. 다만 아직 개발계획 논의 중으로 실물 아파트가 존재하지 않음.
# * 연서면·연동면 또한 대부분이 산지지형, 신도심과 인접한 곳에 개발된 구역 없음, 조치원읍에 인접한 곳에 주거지역 형성, 조치원읍 대형 개발계획 다수
# * 해당 지역들은 상승률이 존재했을 뿐, 가격대 자체는 2023년 상반기 기준 1-2.5억원으로 중간값 이하
# * 신도심은 2023년 상반기 기준 4-7억원
# * 상승률이 없었던 지역은 2023년 상반기 기준 0.4-1억원
# <br>
#
# <h3>상승률이 저조한 지역들 - 신도심('~동') 원거리지역</h3>
#
# * 부강면, 소정면, 전의면, 전동면, 장군면
# * 부강면, 장군면은 신도심과 붙어있으나, 인접한 구역에 개발예정지 없음
#
# <br>
#
# <h3> 등락폭이 컸던 지역들 - 데이터 수 매우 부족 </h3>
#
# * 가람동, 해밀동, 집현동 데이터 수가 각각 1, 20, 11개로 타지역 데이터 수의 0.05% ~ 38.5% 수준
# * 실거래 자료 자체가 매우 부족하여 등락폭이 크게 나타날 수 밖에 없음
# * 가람동의 경우, 데이터가 1개밖에 없어 그래프 상에 나타나지 않음

# %%
# Generate a list of dataframe variables using a loop
df_list = [globals()[f"name{i}"] for i in range(46) if f"name{i}" in globals() and isinstance(globals()[f"name{i}"], pd.DataFrame)]

# Loop through the list and print the lengths
for i, df in enumerate(df_list):
    
    df_name = dong_list[i]
    print(df_name + f" 데이터 수 : {len(df)}")
# Out:
# 금남면 데이터 수 : 204
# 연서면 데이터 수 : 184
# 조치원읍 데이터 수 : 211
# 부강면 데이터 수 : 185
# 소정면 데이터 수 : 131
# 연동면 데이터 수 : 167
# 전의면 데이터 수 : 197
# 전동면 데이터 수 : 70
# 한솔동 데이터 수 : 133
# 나성동 데이터 수 : 108
# 어진동 데이터 수 : 114
# 종촌동 데이터 수 : 113
# 도담동 데이터 수 : 111
# 아름동 데이터 수 : 110
# 장군면 데이터 수 : 58
# 고운동 데이터 수 : 103
# 소담동 데이터 수 : 83
# 보람동 데이터 수 : 76
# 새롬동 데이터 수 : 74
# 대평동 데이터 수 : 65
# 다정동 데이터 수 : 66
# 반곡동 데이터 수 : 52
# 가람동 데이터 수 : 1
# 해밀동 데이터 수 : 20
# 집현동 데이터 수 : 11

# %%
df_list
# Out:
# [     읍면동    계약년월   부번    전용면적(㎡)        계약일      거래금액(만원)          층  \
#  104  금남면  200601  0.0  43.632430  15.925926   4600.370370   6.555556
#  105  금남면  200602  0.0  44.061725  16.437500   4897.812500   6.625000
#  106  금남면  200603  0.0  43.919330  18.783784   4899.594595   8.000000
#  107  금남면  200604  0.0  43.008000  13.421053   4542.631579   7.368421
#  108  금남면  200605  0.0  44.693960  13.000000   4867.200000   7.650000
#  ..   ...     ...  ...        ...        ...           ...        ...
#  303  금남면  202302  0.0  51.437800  25.500000  20900.000000   3.000000
#  304  금남면  202304  0.0  49.986133  17.333333  19883.333333   8.666667
#  305  금남면  202305  0.0  72.374250  21.000000  28250.000000   8.000000
#  306  금남면  202306  0.0  43.008000   9.000000  16350.000000   5.000000
#  307  금남면  202307  0.0  43.008000  11.000000  15500.000000  12.000000
#
#              건축년도  해제사유발생일
#  104  2000.000000      NaN
#  105  2000.000000      NaN
#  106  2000.000000      NaN
# ...
